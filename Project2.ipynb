# %%
#loading the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset

# %%
a=pd.read_csv(r"C:\Users\daksh\Downloads\cardio_train (1).csv",sep=";")
a
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
#checking for null values

# %%
a.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
#EDA

# %%
a.head(20)
# Out:
#     id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0    0  18393       2     168    62.0    110     80            1     1      0
# 1    1  20228       1     156    85.0    140     90            3     1      0
# 2    2  18857       1     165    64.0    130     70            3     1      0
# 3    3  17623       2     169    82.0    150    100            1     1      0
# 4    4  17474       1     156    56.0    100     60            1     1      0
# 5    8  21914       1     151    67.0    120     80            2     2      0
# 6    9  22113       1     157    93.0    130     80            3     1      0
# 7   12  22584       2     178    95.0    130     90            3     3      0
# 8   13  17668       1     158    71.0    110     70            1     1      0
# 9   14  19834       1     164    68.0    110     60            1     1      0
# 10  15  22530       1     169    80.0    120     80            1     1      0
# ...

# %%
a.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
a.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
#plotting the x and y

# %%
x=a.iloc[:,5:12]
x
# Out:
#        ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active
# 0        110     80            1     1      0     0       1
# 1        140     90            3     1      0     0       1
# 2        130     70            3     1      0     0       0
# 3        150    100            1     1      0     0       1
# 4        100     60            1     1      0     0       0
# ...      ...    ...          ...   ...    ...   ...     ...
# 69995    120     80            1     1      1     0       1
# 69996    140     90            2     2      0     0       1
# 69997    180     90            3     1      0     1       0
# 69998    135     80            1     2      0     0       0
# 69999    120     80            2     1      0     0       1
#
# [70000 rows x 7 columns]

# %%
y=a["cardio"]
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
plt.scatter(a["ap_hi"],a["ap_lo"])

# %%
# Now..the aim of the project is to provide comparison by applying algorithms'

# %%
# for logistic regression,knn and svm, we will be using standard scaler since they are sensitive to feature scale but that is not the case for decision tree and random forest

# %%
# import standard scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
transform_x=scaler.fit_transform(x)
transform_x
# Out:
# array([[-0.12218198, -0.0882385 , -0.5393221 , ..., -0.31087913,
#         -0.23838436,  0.49416711],
#        [ 0.07261016, -0.03517999,  2.40079294, ..., -0.31087913,
#         -0.23838436,  0.49416711],
#        [ 0.00767945, -0.14129701,  2.40079294, ..., -0.31087913,
#         -0.23838436, -2.02360695],
#        ...,
#        [ 0.33233302, -0.03517999,  2.40079294, ..., -0.31087913,
#          4.19490608, -2.02360695],
#        [ 0.04014481, -0.0882385 , -0.5393221 , ..., -0.31087913,
#         -0.23838436, -2.02360695],
#        [-0.05725127, -0.0882385 ,  0.93073542, ..., -0.31087913,
#         -0.23838436,  0.49416711]])

# %%
#now we import train_test_split to train and get the accuracy score of the algorithms of linear regression,svm and knn

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(transform_x,y,train_size=0.80)

# %%
xtrain
# Out:
# array([[-0.12218198, -0.14129701, -0.5393221 , ..., -0.31087913,
#         -0.23838436,  0.49416711],
#        [ 0.07261016, -0.03517999, -0.5393221 , ..., -0.31087913,
#         -0.23838436,  0.49416711],
#        [ 0.07261016, -0.03517999,  0.93073542, ..., -0.31087913,
#         -0.23838436,  0.49416711],
#        ...,
#        [-0.05725127, -0.0882385 , -0.5393221 , ..., -0.31087913,
#         -0.23838436,  0.49416711],
#        [-0.05725127, -0.0882385 ,  0.93073542, ..., -0.31087913,
#         -0.23838436, -2.02360695],
#        [-0.18711269, -0.14129701, -0.5393221 , ..., -0.31087913,
#         -0.23838436, -2.02360695]])

# %%
xtest
# Out:
# array([[-0.18711269, -0.0882385 , -0.5393221 , ..., -0.31087913,
#         -0.23838436,  0.49416711],
#        [-0.05725127, -0.0882385 , -0.5393221 , ..., -0.31087913,
#         -0.23838436,  0.49416711],
#        [-0.12218198, -0.14129701, -0.5393221 , ..., -0.31087913,
#         -0.23838436, -2.02360695],
#        ...,
#        [-0.05725127, -0.0882385 ,  2.40079294, ..., -0.31087913,
#         -0.23838436,  0.49416711],
#        [ 0.00767945, -0.0882385 ,  2.40079294, ..., -0.31087913,
#         -0.23838436,  0.49416711],
#        [-0.05725127, -0.0882385 , -0.5393221 , ..., -0.31087913,
#         -0.23838436,  0.49416711]])

# %%
# Support vector machine

# %%
from sklearn.svm import SVC

# %%
svc_model=SVC()

# %%
svc_model.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
ans=svc_model.predict(xtest)
ans
# Out:
# array([0, 0, 0, ..., 1, 1, 0], dtype=int64)

# %%
a1=svc_model.score(xtest,ytest)
print("The accuracy of the support vector machine is",a1)
# Out:
# The accuracy of the support vector machine is 0.7201428571428572

# %%
# Linear Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression()

# %%
log_model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
ans2=log_model.predict(xtest)
ans2
# Out:
# array([0, 0, 0, ..., 1, 1, 0], dtype=int64)

# %%
a2=log_model.score(xtest,ytest)
print("The accuracy of the Linear Regression is",a2)
# Out:
# The accuracy of the Linear Regression is 0.7178571428571429

# %%
#KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model=KNeighborsClassifier(n_neighbors=5)

# %%
knn_model.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
ans3=knn_model.predict(xtest)
ans3
# Out:
# array([0, 0, 0, ..., 1, 1, 0], dtype=int64)

# %%
a3=knn_model.score(xtest,ytest)
print("The accuracy of the knn is",a3)
# Out:
# The accuracy of the knn is 0.6768571428571428

# %%
# Now again importing train_test_split for the decision tree and random forest since..the standard scaler is not for these both algorithms

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.80)

# %%
x_train
# Out:
#        ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active
# 46517     90    100            1     1      1     0       1
# 32530    110     79            3     3      0     0       1
# 28159    140     90            1     2      0     0       1
# 52808    120     80            1     2      0     0       0
# 14752    110     70            1     1      0     0       1
# ...      ...    ...          ...   ...    ...   ...     ...
# 23854    120     70            2     2      0     0       0
# 36891    140     90            1     1      0     0       1
# 63630    120     80            1     1      0     0       1
# 67627    120     80            1     1      0     0       0
# 2041     120     80            1     1      0     0       0
#
# [56000 rows x 7 columns]

# %%
x_test
# Out:
#        ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active
# 58311    150    100            1     1      0     0       0
# 9728     110     60            1     1      1     0       1
# 35611    130     80            2     2      0     0       1
# 543      140     90            3     1      0     0       0
# 13126    120     80            1     1      1     0       1
# ...      ...    ...          ...   ...    ...   ...     ...
# 38458    120     80            1     1      0     0       0
# 132      150     89            2     2      0     0       1
# 26049    120     80            1     1      0     0       1
# 48588    140     90            2     1      0     0       1
# 42381    140     90            1     1      0     0       1
#
# [14000 rows x 7 columns]

# %%
# Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dct_model=DecisionTreeClassifier()

# %%
dct_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
ans4=dct_model.predict(x_test)
ans4
# Out:
# array([1, 0, 1, ..., 0, 1, 1], dtype=int64)

# %%
a4=dct_model.score(x_test,y_test)
print("The accuracy of the decision tree classifier is",a4)
# Out:
# The accuracy of the decision tree classifier is 0.7187142857142857

# %%
#Random forest algorithm

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc_model=RandomForestClassifier(n_estimators=7)

# %%
rfc_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=7)

# %%
ans5=rfc_model.predict(x_test)
ans5
# Out:
# array([1, 0, 1, ..., 0, 1, 1], dtype=int64)

# %%
a5=rfc_model.score(x_test,y_test)
print("The accuracy of the Random forest classifier is",a5)
# Out:
# The accuracy of the Random forest classifier is 0.722

# %%
# Now comparing the algorithms->

# %%
print("The accuracy of the support vector machine is",a1)
print("The accuracy of the Logistic Regression is",a2)
print("The accuracy of the knn is",a3)
print("The accuracy of the decision tree classifier is",a4)
print("The accuracy of the Random forest classifier is",a5)
# Out:
# The accuracy of the support vector machine is 0.7201428571428572
# The accuracy of the Logistic Regression is 0.7178571428571429
# The accuracy of the knn is 0.6768571428571428
# The accuracy of the decision tree classifier is 0.7187142857142857
# The accuracy of the Random forest classifier is 0.722

# %%
# So among the 5 algorithms, the highest accuracy is gained from randomforest

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(ans5,y_test)
cm
# Out:
# array([[5483, 2445],
#        [1447, 4625]], dtype=int64)

# %%
from sklearn.metrics import classification_report

# %%
print("Classification Report:")
print(classification_report(ans5, y_test))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.74      7928
#            1       0.65      0.76      0.70      6072
#
#     accuracy                           0.72     14000
#    macro avg       0.72      0.73      0.72     14000
# weighted avg       0.73      0.72      0.72     14000

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Pred 0', 'Pred 1'], 
            yticklabels=['Actual 0', 'Actual 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(50.722222222222214, 0.5, 'Actual')

# %%
from sklearn.metrics import roc_curve, auc

# Get the predicted probabilities (not just the final prediction)
y_prob = rfc_model.predict_proba(x_test)[:, 1]  # Probabilities for class 1

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate (Recall)')
plt.legend(loc='lower right')
plt.show()

# %%
#The Random Forest model performs well with an accuracy of 72% and an AUC score of 0.77. While accuracy is a useful metric, the ROC AUC provides a more reliable evaluation of the model, especially in cases of class imbalance.
